# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.9 MB 9.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.2/9.9 MB 10.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 8.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 7.9 MB/s  0:00:01
# Using cached numpy-2.4.2-cp314-cp314-win_amd64.whl (12.4 MB)
# ...
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
# ...

# %%
import pandas as pd

# %%
balance = 1000

def append(amount=balance):
    amount =0
    print(amount)

# %%
print(balance)
# Out:
# 1000

# %%
append()
# Out:
# 0

# %%
print(balance)
# Out:
# 1000
